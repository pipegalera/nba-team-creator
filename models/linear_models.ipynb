# %% [markdown]
# # Linear models

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression
import statsmodels.formula.api as smf
from stargazer.stargazer import Stargazer
import matplotlib.pyplot as plt

# %%
print(os.getcwd())
path = 'c:/Users/pipeg/Documents/GitHub/nba-team-creator/'
os.chdir(path)
os.getcwd()
# Out:
# c:\Users\pipeg\Documents\GitHub\nba-team-creator\models
# 'c:\\Users\\pipeg\\Documents\\GitHub\\nba-team-creator'

# %% [markdown]
# ## Loading clean data

# %%
teams = pd.read_csv('out_data/teams_model_data.csv')

# %%
teams
# Out:
#                       Team   Season   W/L%  PER_Unit_1  PER_Unit_2  \
# 0                Utah Jazz  2020/21  0.722        80.4        78.0
# 1             Phoenix Suns  2020/21  0.708        89.1        71.5
# 2       Philadelphia 76ers  2020/21  0.681        93.6        69.8
# 3            Brooklyn Nets  2020/21  0.667        77.9        84.5
# 4     Los Angeles Clippers  2020/21  0.653        92.7        74.9
# ..                     ...      ...    ...         ...         ...
# 650          Atlanta Hawks  1999/00  0.341        77.0        62.7
# 651    Vancouver Grizzlies  1999/00  0.268        76.4        53.5
# 652  Golden State Warriors  1999/00  0.232        69.8        71.3
# 653          Chicago Bulls  1999/00  0.207        58.2        49.7
# 654   Los Angeles Clippers  1999/00  0.183        70.1        63.1
#
#      PER_Unit_combined  PER_Unit_1_Rank  PER_Unit_2_Rank  \
# 0                158.4             18.0              3.0
# ...

# %%
teams.columns
# Out:
# Index(['Team', 'Season', 'W/L%', 'PER_Unit_1', 'PER_Unit_2',
#        'PER_Unit_combined', 'PER_Unit_1_Rank', 'PER_Unit_2_Rank',
#        'PER_Unit_combined_Rank', 'DRtg_Unit_1', 'DRtg_Unit_2',
#        'DRtg_Unit_combined', 'DRtg_Unit_1_Rank', 'DRtg_Unit_2_Rank',
#        'DRtg_Unit_combined_Rank'],
#       dtype='object')

# %% [markdown]
# ## Models

# %%
model_1 = smf.ols(formula = "teams['W/L%'] ~ PER_Unit_combined + DRtg_Unit_combined", data = teams).fit(cov_type='HC3')
model_2 = smf.ols(formula = "teams['W/L%'] ~ PER_Unit_1 + PER_Unit_2 + DRtg_Unit_1 + DRtg_Unit_2", data = teams).fit(cov_type='HC3')
model_3 = smf.ols(formula = "np.log(teams['W/L%']) ~ PER_Unit_1 + PER_Unit_2 + DRtg_Unit_1 + DRtg_Unit_2", data = teams).fit(cov_type='HC3')

# %%
results_table = Stargazer([model_1, model_2, model_3])
results_table
# Out:
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">DRtg_Unit_1</td><td></td><td>-0.002<sup>***</sup></td><td>-0.004<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.000)</td><td>(0.000)</td></tr><tr><td style="text-align:left">DRtg_Unit_2</td><td></td><td>-0.001<sup>***</sup></td><td>-0.003<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.000)</td><td>(0.000)</td></tr><tr><td style="text-align:left">DRtg_Unit_combined</td><td>-0.002<sup>***</sup></td><td></td><td></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td><td></td><td></td></tr><tr><td style="text-align:left">Intercept</td><td>0.946<sup>***</sup></td><td>0.666<sup>***</sup></td><td>-0.440<sup>*</sup
# ...

# %%
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          teams['W/L%']   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     458.7
# Date:                Sun, 23 Jan 2022   Prob (F-statistic):          1.30e-187
# Time:                        12:14:16   Log-Likelihood:                 770.85
# No. Observations:                 655   AIC:                            -1532.
# Df Residuals:                     650   BIC:                            -1509.
# Df Model:                           4
# Covariance Type:                  HC3
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.6659      0.105      6.350      0.000       0.460       0.871
# ...

# %%
model_coeff = model_2.params
model_coeff
# Out:
# Intercept      0.665854
# PER_Unit_1     0.014014
# PER_Unit_2     0.006048
# DRtg_Unit_1   -0.002072
# DRtg_Unit_2   -0.001114
# dtype: float64
